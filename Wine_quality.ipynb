# %% [markdown]
# <a href="https://colab.research.google.com/github/goswamiaman172/Internship/blob/main/Wine_quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dir_path='/content/drive/MyDrive/Project Internship Flip robo/Data/winequality-red.csv'

# %%
Wine_quality = pd.read_csv(dir_path)

# %%
Wine_quality
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
Wine_quality.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
Wine_quality.shape
# Out:
# (1599, 12)

# %%
Wine_quality.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
Wine_quality.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
Wine_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
Wine_quality.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
Wine_quality.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
Wine_quality['quality']= Wine_quality['quality'].apply(lambda x : 'good' if (x >7 or x==7) else( 'not good'))

# %%
Wine_quality[Wine_quality['quality']=='good']
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 7               7.3              0.65         0.00             1.2      0.065
# 8               7.8              0.58         0.02             2.0      0.073
# 16              8.5              0.28         0.56             1.8      0.092
# 37              8.1              0.38         0.28             2.1      0.066
# 62              7.5              0.52         0.16             1.9      0.085
# ...             ...               ...          ...             ...        ...
# 1541            7.4              0.25         0.29             2.2      0.054
# 1544            8.4              0.37         0.43             2.3      0.063
# 1549            7.4              0.36         0.30             1.8      0.074
# 1555            7.0              0.56         0.17             1.7      0.065
# 1584            6.7              0.32         0.44             2.4      0.061
#
# ...

# %%
Wine_quality.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Checking for null values present in Data
Wine_quality.isnull().sum().plot(figsize=(9,6),kind='bar')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,10), facecolor='w')
sns.boxplot(data=Wine_quality)
plt.show()

# %%
#Distribution of outcome variable, Heart Disease
plt.figure(figsize=(10, 10), facecolor='w')
plt.subplots_adjust(right=1.5)
plt.subplot(121)
sns.countplot(x="quality", data=Wine_quality)
plt.title("Count distribution of TenYearCHD", size=20)
plt.subplot(122)
labels=[0,1]
plt.pie(Wine_quality["quality"].value_counts(),autopct="%1.1f%%",labels=labels,colors=["lime","red"])
plt.show()

# %%
numeric_features = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide'
, 'density', 'pH', 'sulphates', 'alcohol']
for feature in numeric_features:
    plt.figure(figsize=(18, 10), facecolor='w')
    sns.distplot(Wine_quality[feature])
    plt.title('{} Distribution'.format(feature), fontsize=20)
    plt.show()
# Out:
# <ipython-input-33-b189fc210e53>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Wine_quality[feature])
# <ipython-input-33-b189fc210e53>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Wine_quality[feature])
# <ipython-input-33-b189fc210e53>:5: UserWarning:
#
# ...

# %%
cormat=Wine_quality.corr()
top_corr_features=cormat.index
plt.figure(figsize=(16,8))
sns.heatmap(abs(Wine_quality[top_corr_features].corr()),cmap='coolwarm',annot=True,annot_kws={'size':15})
# Out:
# <ipython-input-45-a26be5fa3bb1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cormat=Wine_quality.corr()
# <Axes: >

# %% [markdown]
# ## **UNIVARATE ANALYSIS**

# %%
# Function to get plots
def plot(x):
  x,y=x,'quality'
  plt.figure(figsize=(21,7))
  sns.countplot(x=x,hue=y,data=Wine_quality)
  plt.title(x+' vs {}'.format(y),fontsize=20)
  plt.xlabel(x,fontsize=10)
  plt.ylabel(y,fontsize=10)
  plt.show()

# %%
plot('fixed acidity')

# %%
plot('volatile acidity')

# %%
plot('citric acid')

# %%
plot('residual sugar')

# %%
plot('chlorides')

# %%
plot('free sulfur dioxide')

# %%
plot('total sulfur dioxide')

# %%
plot('density')

# %%
plot('pH')

# %%
plot('sulphates')

# %%
plot('alcohol')

# %%
plt.figure(figsize=(20,10), facecolor='w')
sns.boxplot(x="quality",y="fixed acidity",data=Wine_quality)
plt.title("Distribution of quality with respect to fixed acidity", size=20)
plt.show()

# %%
plt.figure(figsize=(20,10), facecolor='w')
sns.boxplot(x="quality",y="volatile acidity",data=Wine_quality)
plt.title("Distribution of quality with respect to volatile acidity", size=20)
plt.show()

# %%
plt.figure(figsize=(20,10), facecolor='w')
sns.boxplot(x="quality",y="citric acid",data=Wine_quality)
plt.title("Distribution of quality with respect to citric acid", size=20)
plt.show()

# %%
plt.figure(figsize=(20,10), facecolor='w')
sns.boxplot(x="quality",y="residual sugar",data=Wine_quality)
plt.title("Distribution of quality with respect to residual sugar" , size=20)
plt.show()

# %%
plt.figure(figsize=(20,10), facecolor='w')
sns.boxplot(x="quality",y="chlorides",data=Wine_quality)
plt.title("Distribution of quality with respect to chlorides" , size=20)
plt.show()

# %%
plt.figure(figsize=(20,10), facecolor='w')
sns.boxplot(x="quality",y="free sulfur dioxide",data=Wine_quality)
plt.title("Distribution of quality with respect to free sulfur dioxide" , size=20)
plt.show()

# %%
plt.figure(figsize=(20,10), facecolor='w')
sns.boxplot(x="quality",y="total sulfur dioxide",data=Wine_quality)
plt.title("Distribution of quality with respect to total sulfur dioxide" , size=20)
plt.show()

# %%
plt.figure(figsize=(20,10), facecolor='w')
sns.boxplot(x="quality",y="pH",data=Wine_quality)
plt.title("Distribution of quality with respect to pH" , size=20)
plt.show()

# %%
plt.figure(figsize=(20,10), facecolor='w')
sns.boxplot(x="quality",y="sulphates",data=Wine_quality)
plt.title("Distribution of quality with respect to sulphates" , size=20)
plt.show()

# %%
plt.figure(figsize=(20,10), facecolor='w')
sns.boxplot(x="quality",y="alcohol",data=Wine_quality)
plt.title("Distribution of quality with respect to alcohol" , size=20)
plt.show()

# %%
#Plotting a linegraph to check the relationship between age and cigsPerDay, totChol, glucose.

graph_5 = df.groupby("quality").mean()
graph_6 = df.groupby("quality").totChol.mean()
graph_7 = df.groupby("quality").glucose.mean()

plt.figure(figsize=(16,10), facecolor='w')
sns.lineplot(data=graph_5, label="cigsPerDay")
sns.lineplot(data=graph_6, label="totChol")
sns.lineplot(data=graph_7, label="glucose")
plt.title("Graph showing totChol and cigsPerDay in every age group.", size=20)
plt.xlabel("age", size=20)
plt.ylabel("count", size=20)
plt.xticks(size=12)
plt.yticks(size=12)

# %%
# //fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
# #        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
# #        'pH', 'sulphates', 'alcohol'
